# %%
#importing csc data into variables
import matplotlib.pyplot as plt 
import pandas as pd



#creating dataframes for each database

churn = pd.read_csv("Df_churn_unificado.csv")
df_churn = pd.DataFrame(churn)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Analise Bivariada

# %% [markdown]
# ### Loocking hipoteses that we create about
# ### Clients with a month are more proprieties to churn | One-month customers are more likely to switch
# ### make binaries combinations about variables with one-month
# ### building contingency table

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7043 non-null   int64
#  1   IDCliente         7043 non-null   object
#  2   Genero            7043 non-null   object
#  3   Mais65anos        7043 non-null   int64
#  4   Casado            7043 non-null   object
#  5   TemDependentes    7043 non-null   object
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
#using function crosstab to build a contingency table, using 2 variaveis the we gonna to compare -quantidade
pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True,margins_name='Total') #margins=True sum all variables
# Out:
# Contract  Month-to-month  One year  Two year  Total
# Churn
# No                  2220      1307      1647   5174
# Yes                 1655       166        48   1869
# Total               3875      1473      1695   7043

# %%
pd.crosstab(df_churn.Churn, df_churn.StreamingTV)
# Out:
# StreamingTV    No  No internet service   Yes
# Churn
# No           1868                 1413  1893
# Yes           942                  113   814

# %%
#using function crosstab to build a contingency table, using 2 variaveis the we gonna to compare - proportion
pd.crosstab(df_churn.Churn, df_churn.Contract, normalize='index', margins=True,margins_name='Total') #margins=True sum all variables
#DO66
# Out:
# Contract  Month-to-month  One year  Two year
# Churn
# No              0.429068  0.252609  0.318322
# Yes             0.885500  0.088818  0.025682
# Total           0.550192  0.209144  0.240664

# %% [markdown]
# #### Considering the total dataset, monthly contract customers represent 55%. however, if only customers who abandoned the service were considered, 88% had a monthly contract. In this way, we can say by association that there is a correlation between the type of contract and churn
