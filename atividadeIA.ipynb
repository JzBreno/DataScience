# %% [markdown]
# questao 7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score # r²
from sklearn.metrics import mean_squared_error # mse

dados = np.linspace(0,20, num=500)
dados
conjtreinamento = dados[:400]
conjtestes = dados[400:]

# %% [markdown]
# questao 8

# %%
x = [0, 3, -1, 4, 3, 5, 2, 10, 2, 4]
y =[0.2, 0.8, 2.4, 6.5, 7.1, 7.5, 7.7, 8.1, 8.9, 10.2]

F = np.polyfit(x,y, 9)
yy = np.polyval(F, x)

print(f'F: ', F)
print(f'yy: ', yy)

plt.plot(x,y, '*', label='Real')
plt.plot(x, yy, 'g--', label='Predição')

plt.xlabel('x')
plt.ylabel('y')
plt.title('REGRESSÃO')
plt.show()

r2 = r2_score(y, yy)  # calculo do R²
print(r2)

mse = mean_squared_error(y, yy)  # calculo do erro quadratico médio
print(mse)

rmse = np.sqrt(mse) # calculo da raíz do erro quadratico médio
print(rmse)
# Out:
# F:  [ 1.25136778e-05  3.09094812e-05 -7.50670409e-04 -1.38392180e-02
#  -6.25936997e-02  1.83634903e+00 -6.84954226e+00  3.90239972e+00
#   1.04378145e+01  2.00000000e-01]
# yy:  [0.2  3.95 2.4  8.35 3.95 7.5  8.3  8.1  8.3  8.35]
# c:\Users\joseb\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3526: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 0.7523133087544278
# 2.7409999999999997
# 1.6555965692160635
